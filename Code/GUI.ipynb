# %%
from PyQt5 import QtCore, QtGui, QtWidgets
import CNN_Cifar
from PyQt5.QtWidgets import QMessageBox
from PyQt5.QtWidgets import QFileDialog
from PyQt5.QtGui import QPixmap
import os, sys
# Out:
# Dataset loading Done

# %%
global cifar

class Ui_Window1(object):
    def setupUi(self, Window1):
        Window1.setObjectName("Window1")
        Window1.resize(800, 600)
        self.centralwidget = QtWidgets.QWidget(Window1)
        self.centralwidget.setObjectName("centralwidget")
        self.title_label = QtWidgets.QLabel(self.centralwidget)
        self.title_label.setGeometry(QtCore.QRect(150, 40, 511, 71))
        font = QtGui.QFont()
        font.setFamily("Times New Roman")
        font.setPointSize(22)
        self.title_label.setFont(font)
        self.title_label.setAlignment(QtCore.Qt.AlignCenter)
        self.title_label.setObjectName("title_label")
        self.train_button = QtWidgets.QPushButton(self.centralwidget)
        self.train_button.setGeometry(QtCore.QRect(340, 280, 120, 31))
        font = QtGui.QFont()
        font.setFamily("Times New Roman")
        font.setPointSize(16)
        self.train_button.setFont(font)
        self.train_button.setObjectName("train_button")
        self.exit_button = QtWidgets.QPushButton(self.centralwidget)
        self.exit_button.setGeometry(QtCore.QRect(630, 480, 101, 31))
        font = QtGui.QFont()
        font.setFamily("Times New Roman")
        font.setPointSize(16)
        self.exit_button.setFont(font)
        self.exit_button.setObjectName("exit_button")
        self.team_label = QtWidgets.QLabel(self.centralwidget)
        self.team_label.setGeometry(QtCore.QRect(290, 130, 181, 71))
        font = QtGui.QFont()
        font.setFamily("Times New Roman")
        font.setPointSize(11)
        self.team_label.setFont(font)
        self.team_label.setStyleSheet("")
        self.team_label.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.team_label.setFrameShadow(QtWidgets.QFrame.Plain)
        self.team_label.setLineWidth(1)
        self.team_label.setAlignment(QtCore.Qt.AlignCenter)
        self.team_label.setWordWrap(False)
        self.team_label.setIndent(-1)
        self.team_label.setObjectName("team_label")
        Window1.setCentralWidget(self.centralwidget)
        self.menubar = QtWidgets.QMenuBar(Window1)
        self.menubar.setGeometry(QtCore.QRect(0, 0, 800, 21))
        self.menubar.setObjectName("menubar")
        Window1.setMenuBar(self.menubar)
        self.statusbar = QtWidgets.QStatusBar(Window1)
        self.statusbar.setObjectName("statusbar")
        Window1.setStatusBar(self.statusbar)
        
        self.train_button.clicked.connect(lambda: self.train_button_pressed(Window1))
        self.exit_button.clicked.connect(self.exit_button_pressed)
        
        self.retranslateUi(Window1)
        QtCore.QMetaObject.connectSlotsByName(Window1)
        
        Window1.setStyleSheet("background-color: #437f8a ;\n" "color: white;")

        self.team_label.setStyleSheet(
            """
            QWidget {
                border: 1px dashed white; 
            }
            """
        )
        
#        self.train_button.setStyleSheet(
        """
            QWidget {
                border: 0.5px solid white;
                border-radius: 5px;
            }

            QWidget:hover {
                border: 2px solid white;
            }
            
        """
#        )
        
        self.train_button.setStyleSheet(
            """
            QWidget {
                border: 0.5px solid white;
                border-radius: 5px;
            }

            QWidget:hover {
                background-color: white;
                color: #437f8a;
                opacity: 0.3;
                border-radius: 10px;
                border: 2px solid white;
            }
            """
        )
    
        self.exit_button.setStyleSheet(
            """
            QWidget {
                border: 0.5px solid white;
                border-radius: 5px;
            }

            QWidget:hover {
                background-color: white;
                color: #437f8a;
                opacity: 0.3;
                border-radius: 10px;
                border: 2px solid white;
            }
            """
        )

    def retranslateUi(self, Window1):
        _translate = QtCore.QCoreApplication.translate
        Window1.setWindowTitle(_translate("Window1", "MainWindow"))
        self.title_label.setText(_translate("Window1", "CIFAR-10 RECOGNITION ENGINE"))
        self.train_button.setText(_translate("Window1", "Load Model"))
        self.exit_button.setText(_translate("Window1", "EXIT"))
        self.team_label.setText(_translate("Window1", "Gokul S. (2018103026)\n"
"Reuel Sam (2018103053)"))

    def train_button_pressed(self, window):
        global cifar
        cifar = CNN_Cifar.CNN()

        cifar.model_load()

        msg2 = QMessageBox()
        msg2.setWindowTitle("Training Complete ")
        msg2.setText("Model has been loaded!")

        
        msg2.setIcon(QMessageBox.Information)
        
        msg2.setDefaultButton(QMessageBox.Ok)
        msg2.exec_()
        self.openWindow(2, window)

    def exit_button_pressed(self):
        global app
        sys.exit(app.exec_())

    def openWindow(self,wno, window):
        self.new_window = QtWidgets.QMainWindow()
        if wno == 2:
            self.ui = Ui_Window2()
        '''elif wno == 3:
            self.ui = Ui_Window3()
        elif wno == 4:
            self.ui = Ui_Window4()
        elif wno == 5:
            self.ui = Ui_Window5()
        '''
        self.ui.setupUi(self.new_window)
        self.new_window.show()

        window.close()



class Ui_Window2(object):
    def setupUi(self, Window2):
        Window2.setObjectName("Window2")
        Window2.resize(800, 600)
        self.centralwidget = QtWidgets.QWidget(Window2)
        self.centralwidget.setObjectName("centralwidget")
        self.title_label = QtWidgets.QLabel(self.centralwidget)
        self.title_label.setGeometry(QtCore.QRect(340, 30, 121, 71))
        font = QtGui.QFont()
        font.setFamily("Times New Roman")
        font.setPointSize(22)
        self.title_label.setFont(font)
        self.title_label.setObjectName("title_label")
        self.accuracy_button = QtWidgets.QPushButton(self.centralwidget)
        self.accuracy_button.setGeometry(QtCore.QRect(310, 170, 171, 41))
        font = QtGui.QFont()
        font.setFamily("Times New Roman")
        font.setPointSize(16)
        self.accuracy_button.setFont(font)
        self.accuracy_button.setObjectName("accuracy_button")
        self.image_button = QtWidgets.QPushButton(self.centralwidget)
        self.image_button.setGeometry(QtCore.QRect(390, 270, 131, 31))
        font = QtGui.QFont()
        font.setFamily("Times New Roman")
        font.setPointSize(12)
        self.image_button.setFont(font)
        self.image_button.setObjectName("image_button")
        self.image_label = QtWidgets.QLabel(self.centralwidget)
        self.image_label.setGeometry(QtCore.QRect(230, 250, 131, 71))
        font = QtGui.QFont()
        font.setFamily("Times New Roman")
        font.setPointSize(16)
        font.setBold(True)
        font.setWeight(75)
        self.image_label.setFont(font)
        self.image_label.setObjectName("image_label")
        self.submit_button = QtWidgets.QPushButton(self.centralwidget)
        self.submit_button.setGeometry(QtCore.QRect(330, 350, 121, 41))
        font = QtGui.QFont()
        font.setFamily("Times New Roman")
        font.setPointSize(14)
        self.submit_button.setFont(font)
        self.submit_button.setObjectName("submit_button")
        self.exit_button = QtWidgets.QPushButton(self.centralwidget)
        self.exit_button.setGeometry(QtCore.QRect(660, 480, 101, 31))
        font = QtGui.QFont()
        font.setFamily("Times New Roman")
        font.setPointSize(16)
        self.exit_button.setFont(font)
        self.exit_button.setObjectName("exit_button")
        Window2.setCentralWidget(self.centralwidget)
        self.menubar = QtWidgets.QMenuBar(Window2)
        self.menubar.setGeometry(QtCore.QRect(0, 0, 800, 21))
        self.menubar.setObjectName("menubar")
        Window2.setMenuBar(self.menubar)
        self.statusbar = QtWidgets.QStatusBar(Window2)
        self.statusbar.setObjectName("statusbar")
        Window2.setStatusBar(self.statusbar)

        
        self.exit_button.clicked.connect(self.exit_button_pressed)
        self.accuracy_button.clicked.connect(self.accuracy_button_pressed)
        self.image_button.clicked.connect(self.image_button_pressed)
        self.submit_button.clicked.connect(self.submit_button_pressed)
        
        
        self.retranslateUi(Window2)
        QtCore.QMetaObject.connectSlotsByName(Window2)

        Window2.setStyleSheet("background-color: #437f8a ;\n" "color: white;")


        self.title_label.setStyleSheet(
            """
            QWidget {
                text-decoration: underline;
            }
            """
        )

        self.image_label.setStyleSheet(
            """
            QWidget {
                letter-spacing: 1px;
            }
            """
        )

        self.accuracy_button.setStyleSheet(
            """
            QWidget {
                border: 0.5px solid white;
                border-radius: 5px;
            }

            QWidget:hover {
                background-color: white;
                color: #437f8a;
                opacity: 0.3;
                border-radius: 10px;
                border: 2px solid white;
            }
            """
        )

        self.image_button.setStyleSheet(
            """
            QWidget {
                border: 0.5px solid white;
                border-radius: 5px;
            }

            QWidget:hover {
                background-color: white;
                color: #437f8a;
                opacity: 0.3;
                border-radius: 10px;
                border: 2px solid white;
            }
            """
        )

        self.submit_button.setStyleSheet(
            """
            QWidget {
                border: 0.5px solid white;
                border-radius: 5px;
            }

            QWidget:hover {
                background-color: white;
                color: #437f8a;
                opacity: 0.3;
                border-radius: 10px;
                border: 2px solid white;
            }
            """
        )

        self.exit_button.setStyleSheet(
            """
            QWidget {
                border: 0.5px solid white;
                border-radius: 5px;
            }

            QWidget:hover {
                background-color: white;
                color: #437f8a;
                opacity: 0.3;
                border-radius: 10px;
                border: 2px solid white;
            }
            """
        )

        

    def retranslateUi(self, Window2):
        _translate = QtCore.QCoreApplication.translate
        Window2.setWindowTitle(_translate("Window2", "MainWindow"))
        self.title_label.setText(_translate("Window2", "RESULT"))
        self.accuracy_button.setText(_translate("Window2", "Show Accuracy"))
        self.image_button.setText(_translate("Window2", "Search for image"))
        self.image_label.setText(_translate("Window2", "Insert Image:"))
        self.submit_button.setText(_translate("Window2", "RECOGNIZE"))
        self.exit_button.setText(_translate("Window2", "EXIT"))

    def image_button_pressed(self):
        #self.filepath
        fp = QFileDialog.getOpenFileName()
        self.image_path = fp[0].split("/")[-2] + "/" + fp[0].split("/")[-1]
        
    def submit_button_pressed(self):
        global cifar
        ret_class = cifar.predict_new(self.image_path)
        
        msg1 = QMessageBox()
        msg1.setWindowTitle("Result: ")
        msg1.setText("The provided image has been recognized as \'"+ret_class+"\'")
        msg1.setIconPixmap(QPixmap(self.image_path))
        msg1.setDefaultButton(QMessageBox.Ok)
        msg1.exec_()
        

    def accuracy_button_pressed(self):
        global cifar

        acc = cifar.model_evaluate()
        #cifar.model_performance_graph()
        msg1 = QMessageBox()
        msg1.setWindowTitle("Accuracy ")
        msg1.setText("Accuracy of trained model is: "+str(acc*100)+"%")
        msg1.setIcon(QMessageBox.Information)
        msg1.setDefaultButton(QMessageBox.Ok)
        msg1.exec_()


    def exit_button_pressed(self):
        global app
        sys.exit(app.exec_())

# %%
app = QtWidgets.QApplication(sys.argv)
Window1 = QtWidgets.QMainWindow()
ui = Ui_Window1()
ui.setupUi(Window1)
Window1.show()
sys.exit(app.exec_())
# Out:
# 10000/10000 - 6s - loss: 1.6367 - accuracy: 0.8241
# 0.8241
# dog
# truck
